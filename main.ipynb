# %%
from src import *
import os

frameworkFolder = os.path.join("C:/", "NDevils", "NDevils2015_master")
simRobotFolder = os.path.join(frameworkFolder, "Build", "Windows", "SimRobot", "Release")
simRobot = os.path.join(simRobotFolder, "SimRobot.exe")
configFolder = os.path.join(frameworkFolder, "Config")
logFolder = os.path.join(configFolder, "Logs")
sceneFolder = os.path.join(configFolder, "Scenes")
scene = os.path.join(sceneFolder, "ReplayRobotCognition.ros2")
sceneCon = os.path.join(sceneFolder, "ReplayRobotCognition.con")

sim = Simulator()
print(simRobot + " " + scene)
sim._set_log_extraction_con_none()
#sim._set_log_extraction_con("action_name", "log_recording_date", 0)
#sim.run("SingleRobotFast")


#update_cfg(JRP_PATH, [("logging = false", "logging = true")])
#update_cfg(JRP_PATH, [("logging = true", "logging = false")])
# Out:
# C:/NDevils\NDevils2015_master\Build\Windows\SimRobot\Release\SimRobot.exe C:/NDevils\NDevils2015_master\Config\Scenes\ReplayRobotCognition.ros2
# ['sl LOG ../log/ThesisFieldLogs/action_name/log_recording_date/0.log\n', '\n', 'call ReplayRobot\n', '\n', 'dr representation:JointRequest\n', 'dr representation:JointSensorData \n', 'dr representation:InertialSensorData \n', 'dr representation:SystemSensorData \n', 'dr representation:FsrSensorData \n', 'dr representation:KeyStates\n', '\n', 'dt 113\n', '\n', 'log start\n']
