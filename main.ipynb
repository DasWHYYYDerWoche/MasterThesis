# %%
import logging
logger = logging.getLogger("global_logger")
logging.basicConfig(filename='info.log',format='%(levelname)s: %(message)s', encoding='utf-8', filemode='w', level=logging.DEBUG)


"""
"""
from src import *
simulator = Simulator()

settings = SimulationParameters("default")
#simulator.extract(mode=ExperimentMode.DEL_EXISTING, action_names=["kick"],recording_dates=["260108"],log_indices=[1])
#simulator.replay(settings=settings, mode=ExperimentMode.DEL_EXISTING, action_names=["kick"],recording_dates=["260108"],log_indices=[1], num_copies=3)

sg = SimulationGapData("default", "kick", "260108", 1)

for name in HINGE_NAMES:
    print(sg.absolute_avg(name))
print()
for name in HINGE_NAMES:
    print(sg.relative_to_target_avg(name))
print()
for name in HINGE_NAMES:
    print(sg.relative_to_range_avg(name))
# Out:
# 0.39629437091115377
# -0.39092406435000004
# -0.8288642307692321
# 0.8348673846153843
# -0.24415304999999868
# -0.046537846153846124
# 0.08578384615384708
# -0.12866692307692254
# -0.7943129842307691
# 0.44031214999999846
# 0.7759061576923078
# 0.26024846153846054
# -0.3451164674538462
# -0.2902206384615385
# 0.8445338461538462
# -0.05446807692307699
# -0.8342139615384617
# 0.2609569703076923
# -0.34480362645384616
# 0.6915876186153845
# 1.8640060384615385
# 0.05164346153846177
# -0.8668778461538461
# -0.4443611639846153
#
# -0.9728867732396917
# -0.9137685709711869
# -0.005001001330758211
# 0.12414335845962159
# 0.29280325696668397
# 0.029382324665904933
# -0.0009358201882009102
# 0.0011363295186521615
# 0.2962440695772733
# 0.2072986261777824
# 0.7023064557245199
# 0.0029112023809029913
# -1.3257647416567022
# -0.12279759088085103
# -0.049991362714037375
# 0.007182252020458941
# -0.08328916552114816
# 2.222432775018482
# -1.3098054273619621
# -0.4364703643652447
# -0.13263087477706872
# 0.004782323678327596
# 0.08912904449211717
# 0.08592347441708063
#
# 0.0016581354431429033
# -0.0057488832992647065
# -0.0034680511747666614
# 0.008881567921440259
# -0.0010215608786610828
# -0.0005380097821253885
# 0.0004104490246595553
# -0.0005383553266816843
# -0.008450138130114568
# 0.0018423102510460182
# 0.008970013383726102
# 0.0012452079499447872
# -0.003193748542049289
# -0.004329712643018626
# 0.007297449634095275
# -0.00043115710380018177
# -0.006893760528373372
# 0.0039036196007134235
# -0.003190853474494227
# 0.010317583449431369
# 0.01610650685614394
# 0.000405460167531301
# -0.007142439203706404
# -0.006646143643203939
