# %%
from src import *



print(simulator._naoV6H25Handler._data)
simulator._thesisCSVReplayHandler.set(5,5,5,5)
simulator._thesisCSVReplayHandler.write_to_file()

simulator._thesisCSVReplayHandler.set_default()
simulator._thesisCSVReplayHandler.write_to_file()
# Out:
# {'HeadYaw': <src.Utils.Hinge.Hinge object at 0x000001EE97A3D2B0>, 'HeadPitch': <src.Utils.Hinge.Hinge object at 0x000001EE97882350>, 'LShoulderPitch': <src.Utils.Hinge.Hinge object at 0x000001EE978825D0>, 'LShoulderRoll': <src.Utils.Hinge.Hinge object at 0x000001EE979BF820>, 'LElbowYaw': <src.Utils.Hinge.Hinge object at 0x000001EE979BF6F0>, 'LElbowRoll': <src.Utils.Hinge.Hinge object at 0x000001EE97A0E9F0>, 'LWristYaw': <src.Utils.Hinge.Hinge object at 0x000001EE9788FBD0>, 'RShoulderPitch': <src.Utils.Hinge.Hinge object at 0x000001EE97A4CAF0>, 'RShoulderRoll': <src.Utils.Hinge.Hinge object at 0x000001EE97847C50>, 'RElbowYaw': <src.Utils.Hinge.Hinge object at 0x000001EE97847D50>, 'RElbowRoll': <src.Utils.Hinge.Hinge object at 0x000001EE97856E40>, 'RWristYaw': <src.Utils.Hinge.Hinge object at 0x000001EE97856F30>, 'LHipYawPitch': <src.Utils.Hinge.Hinge object at 0x000001EE979EB850>, 'LHipRoll': <src.Utils.Hinge.Hinge object at 0x000001EE979EB770>, 'LHipPitch': <src.Utils.Hinge.Hinge obj
# ...
