# %%
import logging
logger = logging.getLogger("global_logger")
logging.basicConfig(filename='info.log',format='%(levelname)s: %(message)s', encoding='utf-8', filemode='w', level=logging.DEBUG)


"""
"""
from src import *
simulator = Simulator()

settings = SimulationParameters("default")
#simulator.extract(mode=ExperimentMode.DEL_EXISTING, action_names=["kick"],recording_dates=["260108"],log_indices=[1])
#simulator.replay(settings=settings, mode=ExperimentMode.DEL_EXISTING, action_names=["kick"],recording_dates=["260108"],log_indices=[1], num_copies=3)

SimulationGapData = SimulationGapData("default", "kick", "260108", 1)
# Out:
# C:\Users\felix\source\repos\NDevils2015\Config\Logs\CSVLogger\replays\paramSet_default\kick\260108
# ['time', 'replayed_frame', 'JSD_headYaw', 'JSD_headPitch', 'JSD_lShoulderPitch', 'JSD_lShoulderRoll', 'JSD_lElbowYaw', 'JSD_lElbowRoll', 'JSD_lWristYaw', 'JSD_lHand', 'JSD_rShoulderPitch', 'JSD_rShoulderRoll', 'JSD_rElbowYaw', 'JSD_rElbowRoll', 'JSD_rWristYaw', 'JSD_rHand', 'JSD_lHipYawPitch', 'JSD_lHipRoll', 'JSD_lHipPitch', 'JSD_lKneePitch', 'JSD_lAnklePitch', 'JSD_lAnkleRoll', 'JSD_rHipYawPitch', 'JSD_rHipRoll', 'JSD_rHipPitch', 'JSD_rKneePitch', 'JSD_rAnklePitch', 'JSD_rAnkleRoll']
# ['time', 'replayed_frame', 'JSD_headYaw', 'JSD_headPitch', 'JSD_lShoulderPitch', 'JSD_lShoulderRoll', 'JSD_lElbowYaw', 'JSD_lElbowRoll', 'JSD_lWristYaw', 'JSD_lHand', 'JSD_rShoulderPitch', 'JSD_rShoulderRoll', 'JSD_rElbowYaw', 'JSD_rElbowRoll', 'JSD_rWristYaw', 'JSD_rHand', 'JSD_lHipYawPitch', 'JSD_lHipRoll', 'JSD_lHipPitch', 'JSD_lKneePitch', 'JSD_lAnklePitch', 'JSD_lAnkleRoll', 'JSD_rHipYawPitch', 'JSD_rHipRoll', 'JSD_rHipPitch', 'JSD_rKneePitch', 'JSD_rAnklePitch', 'JSD_rAnkleRoll']
# ['time', 'replayed_frame', 'JSD_headYaw', 'JSD_headPitch', 'JSD_lShoulderPitch', 'JSD_lShoulderRoll', 'JSD_lElbowYaw', 'JSD_lElbowRoll', 'JSD_lWristYaw', 'JSD_lHand', 'JSD_rShoulderPitch', 'JSD_rShoulderRoll', 'JSD_rElbowYaw', 'JSD_rElbowRoll', 'JSD_rWristYaw', 'JSD_rHand', 'JSD_lHipYawPitch', 'JSD_lHipRoll', 'JSD_lHipPitch', 'JSD_lKneePitch', 'JSD_lAnklePitch', 'JSD_lAnkleRoll', 'JSD_rHipYawPitch', 'JSD_rHipRoll', 'JSD_rHipPitch', 'JSD_rKneePitch', 'JSD_rAnklePitch', 'JSD_rAnkleRoll']
