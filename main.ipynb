# %%
from src import *
from pathlib import Path
import time

import logging
logger = logging.getLogger("global_logger")
logging.basicConfig(filename='info.log',format='%(levelname)s: %(message)s', encoding='utf-8', filemode='w', level=logging.DEBUG)

#print(simulator._thesisLogExtractionHandler._data)

#simulator._thesisLogExtractionHandler.set_values(["logging"], ["test"])
#simulator._thesisLogExtractionHandler.set_value("logging", "test")
#simulator._thesisLogExtractionHandler.set_value("logging1", "test")
#simulator._thesisLogExtractionHandler.set_default()
#simulator._thesisLogExtractionHandler.write_to_file()

sim = Simulator.Simulator()
print(simulator._thesisLogExtractionHandler._data)
print(simulator._thesisLogExtractionHandler._initial_data)
simulator._thesisLogExtractionHandler._set_values(["logging"], ["test"])
print(simulator._thesisLogExtractionHandler._data)
print(simulator._thesisLogExtractionHandler._initial_data)





e1 = ExtractionData("kick", "log_260108", 0)
#e2 = ExtractionData("kick", "log_260108", 1)
#simulator.run_log_extraction([e1,e2])
# Out:
# {'path': ' ${Logfile:,../Logs/*Combined.log}\n'}
# {'path': ' ${Logfile:,../Logs/*Combined.log}\n'}
# {'path': ' ${Logfile:,../Logs/*Combined.log}\n'}
# {'path': ' ${Logfile:,../Logs/*Combined.log}\n'}
