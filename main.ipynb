# %%
from src import *

print(JRP_PATH)
#update_cfg(JRP_PATH, [("logging = false", "logging = true")])
update_cfg(JRP_PATH, [("logging = true", "logging = false")])
# Out:
# C:\Users\felix\source\repos\NDevils2015\Config\jointRequestProvider.cfg
# True
