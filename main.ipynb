# %%
from src import *
from pathlib import Path
import time
from src.Simulator.SimulatorSettings import SimulatorSettings
import logging
logger = logging.getLogger("global_logger")
logging.basicConfig(filename='info.log',format='%(levelname)s: %(message)s', encoding='utf-8', filemode='w', level=logging.DEBUG)


"""
"""



#simulator.replay(mode=ExperimentMode.FULL, action_names=["kick"],recording_dates=["260108"],log_indices=[1], num_copies=1)
# Out:
# 1
# dict_keys(['loggingActive', 'logExtractionActive', 'csvReplayActive', 'logExtractionPath', 'csvReplayPath'])
# ['loggingActive', 'logExtractionActive', 'csvReplayActive', 'logExtractionPath', 'csvReplayPath']
# loggingActive
# logExtractionActive
# csvReplayActive
# logExtractionPath
# csvReplayPath

# %%
from src import *
simulator = Simulator()
simulator.extract(mode=ExperimentMode.DEL_EXISTING, action_names=None, recording_dates=None,log_indices=None)
# Out:
# dict_keys(['loggingActive', 'logExtractionActive', 'csvReplayActive', 'logExtractionPath', 'csvReplayPath'])
# ['loggingActive', 'logExtractionActive', 'csvReplayActive', 'logExtractionPath', 'csvReplayPath']
# loggingActive
# logExtractionActive
# csvReplayActive
# logExtractionPath
# csvReplayPath
# dict_keys(['Kd', 'Kp', 'contactKp', 'contactKd'])
# ['Kp', 'Kd', 'contactKp', 'contactKd']
# Kp
# Kd
# contactKp
# contactKd
# dict_keys(['HeadYaw', 'HeadPitch', 'LShoulderPitch', 'LShoulderRoll', 'LElbowYaw', 'LElbowRoll', 'LWristYaw', 'RShoulderPitch', 'RShoulderRoll', 'RElbowYaw', 'RElbowRoll', 'RWristYaw', 'LHipYawPitch', 'LHipRoll', 'LHipPitch', 'LKneePitch', 'LAnklePitch', 'LAnkleRoll', 'RHipYawPitch', 'RHipRoll', 'RHipPitch', 'RKneePitch', 'RAnklePitch', 'RAnkleRoll'])
# ['HeadYaw', 'HeadPitch', 'LShoulderPitch', 'LShoulderRoll', 'LElbowYaw', 'LElbowRoll', 'LWristYaw', 'RShoulderPitch', 'RShoulderRoll', 'RElbowYaw', 'RElbowRoll', 'RWristYaw', 'LHipYawPitch', 'LHipRoll', 'LHipPitch', 'LKneePitch', 'LAnklePitch', 'LAnkleRoll', 'RHipYawPitch', 'RHipRoll', 'RHipPitch', 'RKneePitch', 'RAnklePitch', 'RAnkleRoll']
# HeadYaw
# HeadPitch
# LShoulderPitch
# LShoulderRoll
# LElbowYaw
# LElbowRoll
# LWristYaw
# RShoulderPitch
# RShoulderRoll
# RElbowYaw
# RElbowRoll
# RWristYaw
# LHipYawPitch
# LHipRoll
# LHipPitch
# LKneePitch
# LAnklePitch
# LAnkleRoll
# RHipYawPitch
# RHipRoll
# RHipPitch
# RKneePitch
# RAnklePitch
# RAnkleRoll
# dict_keys(['path'])
# ['path']
# path
# dict_keys(['loggingActive', 'logExtractionActive', 'csvReplayActive', 'logExtractionPath', 'csvReplayPath'])
# ['loggingActive', 'logExtractionActive', 'csvReplayActive', 'logExtractionPath', 'csvReplayPath']
# loggingActive
# logExtractionActive
# csvReplayActive
# logExtractionPath
# csvReplayPath
# dict_keys(['loggingActive', 'logExtractionActive', 'csvReplayActive', 'logExtractionPath', 'csvReplayPath'])
# ['loggingActive', 'logExtractionActive', 'csvReplayActive', 'logExtractionPath', 'csvReplayPath']
# loggingActive
# logExtractionActive
# csvReplayActive
# logExtractionPath
# csvReplayPath
# dict_keys(['loggingActive', 'logExtractionActive', 'csvReplayActive', 'logExtractionPath', 'csvReplayPath'])
# ['loggingActive', 'logExtractionActive', 'csvReplayActive', 'logExtractionPath', 'csvReplayPath']
# loggingActive
# logExtractionActive
# csvReplayActive
# logExtractionPath
# csvReplayPath
# dict_keys(['loggingActive', 'logExtractionActive', 'csvReplayActive', 'logExtractionPath', 'csvReplayPath'])
# ['loggingActive', 'logExtractionActive', 'csvReplayActive', 'logExtractionPath', 'csvReplayPath']
# loggingActive
# logExtractionActive
# csvReplayActive
# logExtractionPath
# csvReplayPath
# dict_keys(['loggingActive', 'logExtractionActive', 'csvReplayActive', 'logExtractionPath', 'csvReplayPath'])
# ['loggingActive', 'logExtractionActive', 'csvReplayActive', 'logExtractionPath', 'csvReplayPath']
# loggingActive
# logExtractionActive
# csvReplayActive
# logExtractionPath
# csvReplayPath
# dict_keys(['loggingActive', 'logExtractionActive', 'csvReplayActive', 'logExtractionPath', 'csvReplayPath'])
# ['loggingActive', 'logExtractionActive', 'csvReplayActive', 'logExtractionPath', 'csvReplayPath']
# loggingActive
# logExtractionActive
# csvReplayActive
# logExtractionPath
# csvReplayPath
# dict_keys(['loggingActive', 'logExtractionActive', 'csvReplayActive', 'logExtractionPath', 'csvReplayPath'])
# ['loggingActive', 'logExtractionActive', 'csvReplayActive', 'logExtractionPath', 'csvReplayPath']
# loggingActive
# logExtractionActive
# csvReplayActive
# logExtractionPath
# csvReplayPath
# dict_keys(['loggingActive', 'logExtractionActive', 'csvReplayActive', 'logExtractionPath', 'csvReplayPath'])
# ['loggingActive', 'logExtractionActive', 'csvReplayActive', 'logExtractionPath', 'csvReplayPath']
# loggingActive
# logExtractionActive
# csvReplayActive
# logExtractionPath
# csvReplayPath
# dict_keys(['loggingActive', 'logExtractionActive', 'csvReplayActive', 'logExtractionPath', 'csvReplayPath'])
# ['loggingActive', 'logExtractionActive', 'csvReplayActive', 'logExtractionPath', 'csvReplayPath']
# loggingActive
# logExtractionActive
# csvReplayActive
# logExtractionPath
# csvReplayPath
# dict_keys(['loggingActive', 'logExtractionActive', 'csvReplayActive', 'logExtractionPath', 'csvReplayPath'])
# ['loggingActive', 'logExtractionActive', 'csvReplayActive', 'logExtractionPath', 'csvReplayPath']
# loggingActive
# logExtractionActive
# csvReplayActive
# logExtractionPath
# csvReplayPath
# dict_keys(['loggingActive', 'logExtractionActive', 'csvReplayActive', 'logExtractionPath', 'csvReplayPath'])
# ['loggingActive', 'logExtractionActive', 'csvReplayActive', 'logExtractionPath', 'csvReplayPath']
# loggingActive
# logExtractionActive
# csvReplayActive
# logExtractionPath
# csvReplayPath
# dict_keys(['loggingActive', 'logExtractionActive', 'csvReplayActive', 'logExtractionPath', 'csvReplayPath'])
# ['loggingActive', 'logExtractionActive', 'csvReplayActive', 'logExtractionPath', 'csvReplayPath']
# loggingActive
# logExtractionActive
# csvReplayActive
# logExtractionPath
# csvReplayPath
# dict_keys(['loggingActive', 'logExtractionActive', 'csvReplayActive', 'logExtractionPath', 'csvReplayPath'])
# ['loggingActive', 'logExtractionActive', 'csvReplayActive', 'logExtractionPath', 'csvReplayPath']
# loggingActive
# logExtractionActive
# csvReplayActive
# logExtractionPath
# csvReplayPath
# dict_keys(['loggingActive', 'logExtractionActive', 'csvReplayActive', 'logExtractionPath', 'csvReplayPath'])
# ['loggingActive', 'logExtractionActive', 'csvReplayActive', 'logExtractionPath', 'csvReplayPath']
# loggingActive
# logExtractionActive
# csvReplayActive
# logExtractionPath
# csvReplayPath
# dict_keys(['loggingActive', 'logExtractionActive', 'csvReplayActive', 'logExtractionPath', 'csvReplayPath'])
# ['loggingActive', 'logExtractionActive', 'csvReplayActive', 'logExtractionPath', 'csvReplayPath']
# loggingActive
# logExtractionActive
# csvReplayActive
# logExtractionPath
# csvReplayPath
# dict_keys(['loggingActive', 'logExtractionActive', 'csvReplayActive', 'logExtractionPath', 'csvReplayPath'])
# ['loggingActive', 'logExtractionActive', 'csvReplayActive', 'logExtractionPath', 'csvReplayPath']
# loggingActive
# logExtractionActive
# csvReplayActive
# logExtractionPath
# csvReplayPath
# dict_keys(['loggingActive', 'logExtractionActive', 'csvReplayActive', 'logExtractionPath', 'csvReplayPath'])
# ['loggingActive', 'logExtractionActive', 'csvReplayActive', 'logExtractionPath', 'csvReplayPath']
# loggingActive
# logExtractionActive
# csvReplayActive
# logExtractionPath
# csvReplayPath
# dict_keys(['loggingActive', 'logExtractionActive', 'csvReplayActive', 'logExtractionPath', 'csvReplayPath'])
# ['loggingActive', 'logExtractionActive', 'csvReplayActive', 'logExtractionPath', 'csvReplayPath']
# loggingActive
# logExtractionActive
# csvReplayActive
# logExtractionPath
# csvReplayPath
# dict_keys(['loggingActive', 'logExtractionActive', 'csvReplayActive', 'logExtractionPath', 'csvReplayPath'])
# ['loggingActive', 'logExtractionActive', 'csvReplayActive', 'logExtractionPath', 'csvReplayPath']
# loggingActive
# logExtractionActive
# csvReplayActive
# logExtractionPath
# csvReplayPath
# dict_keys(['loggingActive', 'logExtractionActive', 'csvReplayActive', 'logExtractionPath', 'csvReplayPath'])
# ['loggingActive', 'logExtractionActive', 'csvReplayActive', 'logExtractionPath', 'csvReplayPath']
# loggingActive
# logExtractionActive
# csvReplayActive
# logExtractionPath
# csvReplayPath
# dict_keys(['loggingActive', 'logExtractionActive', 'csvReplayActive', 'logExtractionPath', 'csvReplayPath'])
# ['loggingActive', 'logExtractionActive', 'csvReplayActive', 'logExtractionPath', 'csvReplayPath']
# loggingActive
# logExtractionActive
# csvReplayActive
# logExtractionPath
# csvReplayPath
# dict_keys(['loggingActive', 'logExtractionActive', 'csvReplayActive', 'logExtractionPath', 'csvReplayPath'])
# ['loggingActive', 'logExtractionActive', 'csvReplayActive', 'logExtractionPath', 'csvReplayPath']
# loggingActive
# logExtractionActive
# csvReplayActive
# logExtractionPath
# csvReplayPath
# dict_keys(['loggingActive', 'logExtractionActive', 'csvReplayActive', 'logExtractionPath', 'csvReplayPath'])
# ['loggingActive', 'logExtractionActive', 'csvReplayActive', 'logExtractionPath', 'csvReplayPath']
# loggingActive
# logExtractionActive
# csvReplayActive
# logExtractionPath
# csvReplayPath
# dict_keys(['Kd', 'Kp', 'contactKp', 'contactKd'])
# ['Kp', 'Kd', 'contactKp', 'contactKd']
# Kp
# Kd
# contactKp
# contactKd
# dict_keys(['HeadYaw', 'HeadPitch', 'LShoulderPitch', 'LShoulderRoll', 'LElbowYaw', 'LElbowRoll', 'LWristYaw', 'RShoulderPitch', 'RShoulderRoll', 'RElbowYaw', 'RElbowRoll', 'RWristYaw', 'LHipYawPitch', 'LHipRoll', 'LHipPitch', 'LKneePitch', 'LAnklePitch', 'LAnkleRoll', 'RHipYawPitch', 'RHipRoll', 'RHipPitch', 'RKneePitch', 'RAnklePitch', 'RAnkleRoll'])
# ['HeadYaw', 'HeadPitch', 'LShoulderPitch', 'LShoulderRoll', 'LElbowYaw', 'LElbowRoll', 'LWristYaw', 'RShoulderPitch', 'RShoulderRoll', 'RElbowYaw', 'RElbowRoll', 'RWristYaw', 'LHipYawPitch', 'LHipRoll', 'LHipPitch', 'LKneePitch', 'LAnklePitch', 'LAnkleRoll', 'RHipYawPitch', 'RHipRoll', 'RHipPitch', 'RKneePitch', 'RAnklePitch', 'RAnkleRoll']
# HeadYaw
# HeadPitch
# LShoulderPitch
# LShoulderRoll
# LElbowYaw
# LElbowRoll
# LWristYaw
# RShoulderPitch
# RShoulderRoll
# RElbowYaw
# RElbowRoll
# RWristYaw
# LHipYawPitch
# LHipRoll
# LHipPitch
# LKneePitch
# LAnklePitch
# LAnkleRoll
# RHipYawPitch
# RHipRoll
# RHipPitch
# RKneePitch
# RAnklePitch
# RAnkleRoll
# dict_keys(['path'])
# ['path']
# path
