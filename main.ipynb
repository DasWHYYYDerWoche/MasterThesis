# %%
import numpy as np
from pathlib import Path
import numpy as np
import logging

import src
from src import *
logger = logging.getLogger("global_logger")
logging.basicConfig(filename='info.log',format='%(asctime)s - %(levelname)s: %(message)s', encoding='utf-8', filemode='w', level=logging.DEBUG, datefmt="%Y-%m-%d %H:%M:%S")
logger.info("NEW START")

simulator = SimulatorHandler()
simulator.num_instances = 1
simulator.replay(settings = SimulationParameters("default"), data=[("kick", "260108", 1), ("kick", "260108", 2), ("kick", "260108", 3)],mode= ExperimentMode.DEL_EXISTING)
# Out:
# 0
# 2
# 2
# 3

# %%
"""

loggingMode = 1;
logExtractionPath = [logsAsCSVs/kick/260108/1,logsAsCSVs/kick/260108/2,logsAsCSVs/kick/260108/3];
csvReplayPath = [replays/paramSet_default/kick/260108/1_replayed_,replays/paramSet_default/kick/260108/2_replayed_,replays/paramSet_default/kick/260108/3_replayed_];
moveRobot = [2,2,2];
recordingDuration = -1;



"""
# Out:
# [[]]
