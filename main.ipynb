# %%
from src import *
from pathlib import Path
import time
from src.Simulator.SimulatorSettings import SimulatorSettings

settings = SimulatorSettings("1")
settings._kd = 1
settings.save_to_file()
loaded = SimulatorSettings("2")
print(loaded._kd)
loaded2 = SimulatorSettings("1")
print(loaded2._kd)

import logging
logger = logging.getLogger("global_logger")
logging.basicConfig(filename='info.log',format='%(levelname)s: %(message)s', encoding='utf-8', filemode='w', level=logging.DEBUG)

simulator = Simulator()
action_names = ["3"]
recording_dates = None
log_indices = [0]


#simulator.replay(repetitions=2, action_names=["kick"], log_indices=[1])
#simulator.extract(mode=ExperimentMode.DEL_EXISTING, action_names=["kick"],recording_dates=["260108"],log_indices=[1,2,3])
#simulator.replay(mode=ExperimentMode.FULL, action_names=["kick"],recording_dates=["260108"],log_indices=[1], num_copies=1)
# Out:
# 0
# 1
