# %%
from src import *

sim = Simulator()
# Out:
# HeadYaw : H: 4.75408,4.0,20.0,0.0,0.0,
# HeadPitch : H: 4.13659,5.0,20.0,0.0,0.0,
# LShoulderPitch : H: 4.75408,4.0,20.0,0.0,0.0,
# LShoulderRoll : H: 4.13659,5.0,20.0,0.0,0.0,
# LElbowYaw : H: 4.75408,4.0,20.0,0.0,0.0,
# LElbowRoll : H: 4.13659,5.0,20.0,0.0,0.0,
# LWristYaw : H: 14.15817,4.0,20.0,0.0,0.0,
# RShoulderPitch : H: 4.75408,4.0,20.0,0.0,0.0,
# RShoulderRoll : H: 4.13659,5.0,20.0,0.0,0.0,
# RElbowYaw : H: 4.75408,4.0,20.0,0.0,0.0,
# RElbowRoll : H: 4.13659,5.0,20.0,0.0,0.0,
# RWristYaw : H: 14.15817,4.0,20.0,0.0,0.0,
# LHipYawPitch : H: 2.393,14.8,20.0,0.0,0.0,
# LHipRoll : H: 2.393,14.8,20.0,0.0,0.0,
# LHipPitch : H: 3.68137,9.8,20.0,0.0,0.0,
# LKneePitch : H: 3.68137,9.8,20.0,0.0,0.0,
# LAnklePitch : H: 3.68137,9.8,20.0,0.0,0.0,
# LAnkleRoll : H: 2.393,14.8,20.0,0.0,0.0,
# RHipYawPitch : H: 2.393,14.8,20.0,0.0,0.0,
# RHipRoll : H: 2.393,14.8,20.0,0.0,0.0,
# RHipPitch : H: 3.68137,9.8,20.0,0.0,0.0,
# RKneePitch : H: 3.68137,9.8,20.0,0.0,0.0,
# ...
