# %%
import logging
logger = logging.getLogger("global_logger")
logging.basicConfig(filename='info.log',format='%(levelname)s: %(message)s', encoding='utf-8', filemode='w', level=logging.DEBUG)
logger.info("NEW START")

"""
"""
from src import *
simulator = Simulator()
simulator.batch_size = 5
settings = SimulationParameters("default")
#simulator.extract([("kick", "260108", "1")], ExperimentMode.DEL_EXISTING)
#simulator.replay(settings, [("kick", "260108", "1")], ExperimentMode.DEL_EXISTING)
name = "test"
optimizer = SimOptimizer(PARAMETERS_GLOBAL_0, PARAMETERS_PER_TYPE_0, [("kick", "260108", "1")])
result = optimizer.run(0)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[1], line 16
#      14 name = "test"
#      15 optimizer = SimOptimizer(PARAMETERS_GLOBAL_0, PARAMETERS_PER_TYPE_0, [("kick", "260108", "1")])
# ---> 16 result = optimizer.run(0)
#
# File ~\PycharmProjects\Thesis\src\Optimizer\SimOptimizer.py:138, in SimOptimizer.run(self, seed)
#     134 stats.register("max", np.max)
#     136 halloffame = tools.HallOfFame(1)
# --> 138 population, logbook = algorithms.eaSimple(
#     139     population,
#     140     self._toolbox,
#     141     halloffame=halloffame,
#     142     cxpb=self._crossover_pb,
#     143     mutpb=self._mutation_pb,
#     144     ngen=self._max_gen)
#     145 return population, logbook
#
# File ~\PycharmProjects\Thesis\.venv\Lib\site-packages\deap\algorithms.py:151, in eaSimple(population, toolbox, cxpb, mutpb, ngen, stats, halloffame, verbose)
#     149 invalid_ind = [ind for ind in population if not ind.fitness.valid]
#     150 fitnesses = toolbox.map(toolbox.evaluate, invalid_ind)
# --> 151 for ind, fit in zip(invalid_ind, fitnesses):
#     152     ind.fitness.values = fit
#     154 if halloffame is not None:
#
# File ~\PycharmProjects\Thesis\src\Optimizer\SimOptimizer.py:38, in evaluate(experiments, simulator, global_attribute_names, per_joint_type_attribute_names, individual)
#      36     name = split_name[1]
#      37     joint_type = int(split_name[2])
# ---> 38     simulator_parameters.set_for_joint_type(joint_type, name, individual[i])
#      39     i += 1
#      41 # Run simulation
#
# File ~\PycharmProjects\Thesis\src\Utils\SimulationParameters.py:111, in SimulationParameters.set_for_joint_type(self, joint_type, parameter_name, value)
#     110 def set_for_joint_type(self, joint_type : int, parameter_name : str, value : Any):
# --> 111     for joint in [self._joint_parameters[joint_name] for joint_name in JOINT_TYPES[joint_type]]:
#     112         setattr(joint, parameter_name, value)
#
# KeyError: 'lHipYawPitch'
