# %%
from src import *

sim = Simulator()

print(sim._naoV6H25Handler._data)
sim._thesisCSVReplayHandler.set(5,5,5,5)
sim._thesisCSVReplayHandler.write_to_file()

sim._thesisCSVReplayHandler.set_default()
sim._thesisCSVReplayHandler.write_to_file()
# Out:
# {'HeadYaw': <src.Simulator.Utils.Hinge object at 0x000001AA9326C440>, 'HeadPitch': <src.Simulator.Utils.Hinge object at 0x000001AA9326C4B0>, 'LShoulderPitch': <src.Simulator.Utils.Hinge object at 0x000001AA9326C520>, 'LShoulderRoll': <src.Simulator.Utils.Hinge object at 0x000001AA9326C3D0>, 'LElbowYaw': <src.Simulator.Utils.Hinge object at 0x000001AA9326C360>, 'LElbowRoll': <src.Simulator.Utils.Hinge object at 0x000001AA9326C280>, 'LWristYaw': <src.Simulator.Utils.Hinge object at 0x000001AA9326C2F0>, 'RShoulderPitch': <src.Simulator.Utils.Hinge object at 0x000001AA9326C210>, 'RShoulderRoll': <src.Simulator.Utils.Hinge object at 0x000001AA9326C0C0>, 'RElbowYaw': <src.Simulator.Utils.Hinge object at 0x000001AA9326C130>, 'RElbowRoll': <src.Simulator.Utils.Hinge object at 0x000001AA9326C1A0>, 'RWristYaw': <src.Simulator.Utils.Hinge object at 0x000001AA9326C050>, 'LHipYawPitch': <src.Simulator.Utils.Hinge object at 0x000001AA9326F850>, 'LHipRoll': <src.Simulator.Utils.Hinge object at 0x00
# ...
