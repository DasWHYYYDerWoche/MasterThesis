# %%
import logging
logger = logging.getLogger("global_logger")
logging.basicConfig(filename='info.log',format='%(levelname)s: %(message)s', encoding='utf-8', filemode='w', level=logging.DEBUG)
logger.info("NEW START")

"""
"""
from src import *
simulator = Simulator()
simulator.batch_size = 1
settings = SimulationParameters("default")
simulator.extract([("standup_front", "260108", None)], ExperimentMode.DEL_EXISTING)
simulator.replay(settings, [("standup_front", "260108", None)], ExperimentMode.DEL_EXISTING)
#name = "test"
#optimizer = SimOptimizer(PARAMETERS_GLOBAL_0, PARAMETERS_PER_TYPE_0, [("kick", "260108", 1)], population_size=5, max_gen=10)
#result = optimizer.run(0)
