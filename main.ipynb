# %%
from src import *
from pathlib import Path
import time

import logging
logger = logging.getLogger("global_logger")
logging.basicConfig(filename='info.log',format='%(levelname)s: %(message)s', encoding='utf-8', filemode='w', level=logging.DEBUG)

simulator = Simulator()

print([str(e) for e in LogExtractor._get_log_files()])

e1 = ExtractionData("kick", "260108", 0)
e2 = ExtractionData("kick", "260108", 1)
simulator.run_log_extraction([e1,e2])
# Out:
# ['kick/260108/0', 'kick/260108/1', 'kick/260108/2', 'kick/260108/3', 'kick/260108/4', 'kick/260108/5', 'kick/260108/6', 'sidestep/260108/0', 'sidestep/260108/1', 'sidestep/260108/2', 'sidestep/260108/3', 'sidestep/260108/4', 'turn/260108/0', 'turn/260108/1', 'turn/260108/2', 'turn/260108/3', 'turn/260108/4', 'walk/260108/0', 'walk/260108/1', 'walk/260108/2', 'walk/260108/3', 'walk/260108/4']
