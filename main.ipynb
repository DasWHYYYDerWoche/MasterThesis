# %%
from src import *

sim = Simulator()

l = LoggerHandler()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 7
#       4 sim = Simulator()
#       6 l = LoggerCfg()
# ----> 7 t = Test()
#       9 l._write_to_file()
#
# File ~\PycharmProjects\Thesis\src\Simulator\CfgFile.py:73, in Test.__init__(self)
#      72 def __init__(self):
# ---> 73     super().__init__(Path("wrong path"))
#
# File ~\PycharmProjects\Thesis\src\Simulator\CfgFile.py:11, in Cfg.__init__(self, path)
#      10 def __init__(self, path : Path):
# ---> 11     super().__init__(path)
#
# File ~\PycharmProjects\Thesis\src\Simulator\ConfigurationFile.py:11, in ConfigurationFile.__init__(self, path)
#       9 self._data : dict = {}
#      10 self._different_from_file = False
# ---> 11 self._load()
#
# File ~\PycharmProjects\Thesis\src\Simulator\CfgFile.py:16, in Cfg._load(self)
#      14 @override
#      15 def _load(self) -> bool:
# ...
