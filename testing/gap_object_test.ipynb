# %%
from src import *
import matplotlib.pyplot as plt

logger = logging.getLogger("global_logger")
logging.basicConfig(filename='../gap_object_test.log', format='%(levelname)s: %(message)s', encoding='utf-8', filemode='w', level=logging.DEBUG)
logger.info("Starting gap_object_test.")

replay_settings = SimulationParameters("default")
simulator = Simulator()

gap_handler = simulator.simulation_gap(settings=replay_settings)
gap_handler.set_scale_factors(*gap_handler.get_scale_factors())

# define which logs to use for testing
action_name = "kick"
recording_date = "260108"
log_index = 1
joint_name = "lAnklePitch"
start_index = 0
end_index = -1

gap_handler_visualizer = GapHandlerVisualizer(gap_handler)
gap_object_visualizer = gap_handler_visualizer.get_gap_object_visualizer(action_name, recording_date, log_index)

test_object = gap_handler.get(action_name, recording_date, log_index)

# %%
x_axis = test_object.get_time_steps(start_index, end_index)
extraction = test_object.get_gyro_pos_extraction(start_index=start_index, end_index=end_index)
replay = test_object.get_gyro_pos_replay(start_index=start_index, end_index=end_index)
y_label = "Position (degrees)/Velocity (?)/Acceleration (?)"

plt.figure(figsize=(20, 5))
plt.title("Gyro Orientation")
plt.xlabel("time step")
plt.ylabel("gyro orientation in degrees")
plt.grid(visible=True)
plt.plot(x_axis, extraction[0], linestyle="-", color="mistyrose", label="e_x", marker=".")
plt.plot(x_axis, extraction[1], linestyle="-", color="red", label="e_y", marker=".")
plt.plot(x_axis, extraction[2], linestyle="-", color="darkred", label="e_z", marker=".")
plt.plot(x_axis, replay[0], linestyle="-", label="r_x", color="lightblue", marker=".")
plt.plot(x_axis, replay[1], linestyle="-", label="r_y", color="blue", marker=".")
plt.plot(x_axis, replay[2], linestyle="-", label="r_z", color="darkblue", marker=".")
plt.legend()
plt.show()

extraction = test_object.get_gyro_vel_extraction(start_index=start_index, end_index=end_index)
replay = test_object.get_gyro_vel_replay(start_index=start_index, end_index=end_index)

plt.figure(figsize=(20, 5))
plt.title("Gyro Velocity")
plt.xlabel("time step")
plt.ylabel("gyro velocity in deg/s")
plt.grid(visible=True)
plt.plot(x_axis, extraction[0], linestyle="-", color="mistyrose", label="e_x", marker=".")
plt.plot(x_axis, extraction[1], linestyle="-", color="red", label="e_y", marker=".")
plt.plot(x_axis, extraction[2], linestyle="-", color="darkred", label="e_z", marker=".")
plt.plot(x_axis, replay[0], linestyle="-", label="r_x", color="lightblue", marker=".")
plt.plot(x_axis, replay[1], linestyle="-", label="r_y", color="blue", marker=".")
plt.plot(x_axis, replay[2], linestyle="-", label="r_z", color="darkblue", marker=".")
plt.legend()
plt.show()

extraction = test_object.get_gyro_acc_extraction(start_index=start_index, end_index=end_index)
replay = test_object.get_gyro_acc_replay(start_index=start_index, end_index=end_index)

plt.figure(figsize=(20, 5))
plt.title("Gyro Acceleration")
plt.xlabel("time step")
plt.ylabel("gyro acceleration in deg/s^2")
plt.grid(visible=True)
plt.plot(x_axis, extraction[0], linestyle="-", color="mistyrose", label="e_x", marker=".")
plt.plot(x_axis, extraction[1], linestyle="-", color="red", label="e_y", marker=".")
plt.plot(x_axis, extraction[2], linestyle="-", color="darkred", label="e_z", marker=".")
plt.plot(x_axis, replay[0], linestyle="-", label="r_x", color="lightblue", marker=".")
plt.plot(x_axis, replay[1], linestyle="-", label="r_y", color="blue", marker=".")
plt.plot(x_axis, replay[2], linestyle="-", label="r_z", color="darkblue", marker=".")
plt.legend()
plt.show()

# %%
x_axis = test_object.get_time_steps(start_index, end_index)
extraction = test_object.get_accelerometer_pos_extraction(start_index=start_index, end_index=end_index)
replay = test_object.get_accelerometer_pos_replay(start_index=start_index, end_index=end_index)
y_label = "Position (degrees)/Velocity (?)/Acceleration (?)"
print(extraction)
plt.figure(figsize=(20, 5))
plt.title("Accelerometer Position")
plt.xlabel("time step")
plt.ylabel("Accelerometer position in m")
plt.grid(visible=True)
plt.plot(x_axis, extraction[0], linestyle="-", color="mistyrose", label="e_x", marker=".")
plt.plot(x_axis, extraction[1], linestyle="-", color="red", label="e_y", marker=".")
plt.plot(x_axis, extraction[2], linestyle="-", color="darkred", label="e_z", marker=".")
plt.plot(x_axis, replay[0], linestyle="-", label="r_x", color="lightblue", marker=".")
plt.plot(x_axis, replay[1], linestyle="-", label="r_y", color="blue", marker=".")
plt.plot(x_axis, replay[2], linestyle="-", label="r_z", color="darkblue", marker=".")
plt.legend()
plt.show()

extraction = test_object.get_accelerometer_vel_extraction(start_index=start_index, end_index=end_index)
replay = test_object.get_accelerometer_vel_replay(start_index=start_index, end_index=end_index)

plt.figure(figsize=(20, 5))
plt.title("Accelerometer Velocity")
plt.xlabel("time step")
plt.ylabel("Accelerometer velocity in m/s")
plt.grid(visible=True)
plt.plot(x_axis, extraction[0], linestyle="-", color="mistyrose", label="e_x", marker=".")
plt.plot(x_axis, extraction[1], linestyle="-", color="red", label="e_y", marker=".")
plt.plot(x_axis, extraction[2], linestyle="-", color="darkred", label="e_z", marker=".")
plt.plot(x_axis, replay[0], linestyle="-", label="r_x", color="lightblue", marker=".")
plt.plot(x_axis, replay[1], linestyle="-", label="r_y", color="blue", marker=".")
plt.plot(x_axis, replay[2], linestyle="-", label="r_z", color="darkblue", marker=".")
plt.legend()
plt.show()

extraction = test_object.get_accelerometer_acc_extraction(start_index=start_index, end_index=end_index)
replay = test_object.get_accelerometer_acc_replay(start_index=start_index, end_index=end_index)

plt.figure(figsize=(20, 5))
plt.title("Accelerometer Acceleration")
plt.xlabel("time step")
plt.ylabel("Accelerometer acceleration in m/s^2")
plt.grid(visible=True)
plt.plot(x_axis, extraction[0], linestyle="-", color="mistyrose", label="e_x", marker=".")
plt.plot(x_axis, extraction[1], linestyle="-", color="red", label="e_y", marker=".")
plt.plot(x_axis, extraction[2], linestyle="-", color="darkred", label="e_z", marker=".")
plt.plot(x_axis, replay[0], linestyle="-", label="r_x", color="lightblue", marker=".")
plt.plot(x_axis, replay[1], linestyle="-", label="r_y", color="blue", marker=".")
plt.plot(x_axis, replay[2], linestyle="-", label="r_z", color="darkblue", marker=".")
plt.legend()
plt.show()
# Out:
# ([nan, nan, np.float64(3.6963504e-06), np.float64(1.11567888e-05), np.float64(2.0649686399999995e-05), np.float64(4.363478799999979e-06), np.float64(-0.00013010109559999996), np.float64(-0.00037195798999999986), np.float64(-0.0006858862222000002), np.float64(-0.0011601934486000001), np.float64(-0.0018434572272), np.float64(-0.0026461025736), np.float64(-0.0035279574178000007), np.float64(-0.004730878984399999), np.float64(-0.0059803883948), np.float64(-0.007241903223000001), np.float64(-0.0088611140266), np.float64(-0.010453641481000002), np.float64(-0.011980740243199998), np.float64(-0.013838037115799999), np.float64(-0.0155580776286), np.float64(-0.0172642878486), np.float64(-0.0189097050126), np.float64(-0.020453159664600002), np.float64(-0.021873893484600004), np.float64(-0.0231505884246), np.float64(-0.0242635078446), np.float64(-0.0251930015046), np.float64(-0.0259280087646), np.float64(-0.0264596880246), np.float64(-0.0268162676046), np.float64(-0.026971621584599998), np.float64(-0.026907293484599998), np.float64(-0.026608665864599996), np.float64(-0.026062983204599995), np.float64(-0.025261935264599997), np.float64(-0.024201310044599997), np.float64(-0.022879182264599996), np.float64(-0.021294899604599994), np.float64(-0.01944966302459999), np.float64(-0.0173464274046), np.float64(-0.015045151464599997), np.float64(-0.012597009924599995), np.float64(-0.010024105632599992), np.float64(-0.007307198460599988), np.float64(-0.0044206031285999835), np.float64(-0.0013080228365999792), np.float64(0.0021343649754000256), np.float64(0.005929367027399993), np.float64(0.010065422999399996), np.float64(0.0145187167314), np.float64(0.019310970623400005), np.float64(0.02447906739540001), np.float64(0.029997271367400016), np.float64(0.03583553261940002), np.float64(0.041971591631400025), np.float64(0.04822898403540003), np.float64(0.05465036939940004), np.float64(0.061268808683400046), np.float64(0.0681217260474), np.float64(0.0751330002114), np.float64(0.0829023400624), np.float64(0.08956932655340001), np.float64(0.09692970906140001), np.float64(0.10445999284940002), np.float64(0.11226200751740004), np.float64(0.12098017072440004), np.float64(0.12851319467340006), np.float64(0.13691595802140005), np.float64(0.1462212260584), np.float64(0.1549710914464), np.float64(0.16387558259440002), np.float64(0.17284983454240002), np.float64(0.18198541257040002), np.float64(0.19136603971840002), np.float64(0.20098221630640004), np.float64(0.21080874377440004), np.float64(0.22081981876240003), np.float64(0.23097634527040004), np.float64(0.24124002505839995), np.float64(0.2515927728784), np.float64(0.2620191648904), np.float64(0.2724961132864), np.float64(0.2829903076984), np.float64(0.2934745608544), np.float64(0.3039248206504), np.float64(0.3142890091984), np.float64(0.32457715494640005), np.float64(0.33475612709440006), np.float64(0.3448275210184001), np.float64(0.3548207066704001), np.float64(0.36477163163440013), np.float64(0.37469500795840016), np.float64(0.38463723705040015), np.float64(0.39464418060640016), np.float64(0.4047743815384), np.float64(0.4150526202304), np.float64(0.42550344148240005), np.float64(0.43614667697440007), np.float64(0.4469958252664001), np.float64(0.4580559594784001), np.float64(0.46932459561040013), np.float64(0.4808060291824001), np.float64(0.4924891477144001), np.float64(0.5043465609664001), np.float64(0.5163528010984001), np.float64(0.5284969602544001), np.float64(0.5407701827224001), np.float64(0.5531644746304001), np.float64(0.5656768321384001), np.float64(0.5783041933744002), np.float64(0.5910460350424002), np.float64(0.6039218355904001), np.float64(0.6169392572584002), np.float64(0.6301031902864002), np.float64(0.6434042141944002), np.float64(0.6579746627234001), np.float64(0.6704151694834), np.float64(0.6841082935474), np.float64(0.6979053604114), np.float64(0.7117920894514), np.float64(0.7269220422374002), np.float64(0.7409523514454002)], [nan, nan, np.float64(3.6963504e-06), np.float64(1.11567888e-05), np. ...

# %%
gap_object_visualizer.plt_extraction(joint_name, line_type="-")
gap_object_visualizer.plt_replay(joint_name, line_type="-")

# %%
gap_object_visualizer.plt_pos_gap(joint_name,line_type="-")
gap_object_visualizer.plt_vel_gap(joint_name,line_type="-")
gap_object_visualizer.plt_acc_gap(joint_name,line_type="-")

# %%
gap_object_visualizer.plt_total_gap(joint_name, line_type="-")

# %%
gap_object_visualizer.plt_avg_for_frames(line_type="-")

# %%
gap_object_visualizer.plt_avg_for_joints()

# %%
print(test_object.get_pos_gap_avg())
print(test_object.get_vel_gap_avg())
print(test_object.get_acc_gap_avg())
print(test_object.get_total_gap_avg())
# Out:
# 0.0002687410672017332
# 0.00496710715380681
# 0.0022652634965438503
# 0.007501111717552393

# %%
import matplotlib.pyplot as plt
pos_gap_plot = test_object.get_pos_gaps()

plt.figure(figsize=(20, 5))
plt.title("gap of the position, velocity, acceleration and their sum averaged over all frames")
plt.xlabel("joint")
plt.ylabel("pos/vel/acc/total gap")
plt.boxplot(pos_gap_plot.values(), tick_labels=[ABBREVIATIONS[key] for key in pos_gap_plot.keys()])
plt.legend()
plt.show()
# Out:
# C:\Users\felix\AppData\Local\Temp\ipykernel_25760\1031213708.py:9: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
